# %% [markdown]
# # Constantes

# %%
import math
math.pi
math.e
# Out:
# 2.718281828459045

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.tau
# Out:
# 6.283185307179586

# %%
math.inf
# Out:
# inf

# %%
math.exp(1)
# Out:
# 2.718281828459045

# %%
math.log10(100)
# Out:
# 2.0

# %%
math.exp(1)
# Out:
# 2.718281828459045

# %%
math.remainder(7,3)
# Out:
# 1.0

# %%
7/3
# Out:
# 2.3333333333333335

# %%
7//3
# Out:
# 2

# %%
math.fmod(7,3)
# Out:
# 1.0

# %%
7%3
# Out:
# 1
